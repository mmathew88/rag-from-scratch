# %% [markdown]
# ## Week 1 reflection
#
# ### What I built - week 1 set up for my RAG project
# ### Three things that clicked -
# ### Two things still fuzzy
# ### How does testing an LLM differ from testing deterministic code?
# ### What do I want to understand first in Week 2?
